# %%
import shutil
import os

source_dir = "/kaggle/input/pairre-tkbc"
destination_dir = "/kaggle/working/pairre-tkbc"

if os.path.exists(destination_dir):
    shutil.rmtree(destination_dir)

shutil.copytree(source_dir, destination_dir)
print("Copy dataset thành công")
# Out:
# Copy dataset thành công

# %%
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
# Out:
# PyTorch version: 2.8.0+cu126
# CUDA available: True

# %%
# %%writefile requirements.txt
# tqdm
# numpy
# scikit-learn
# scipy
# Out:
# Writing requirements.txt

# %%
# !pip install -r requirements.txt

# %%
# %cd /kaggle/working
# !git clone https://github.com/MichaelPham2005/PaiRe-tkbc.git
# Out:
# /kaggle/working
# Cloning into 'PaiRe-tkbc'...
# remote: Enumerating objects: 54, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 54 (delta 17), reused 43 (delta 11), pack-reused 0 (from 0)
# Receiving objects: 100% (54/54), 47.88 KiB | 6.84 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %%
# !python /kaggle/working/my_code/tkbc/process_icews.py
# Out:
# python3: can't open file '/kaggle/working/my_code/tkbc/process_icews.py': [Errno 2] No such file or directory

# %%
# !python /kaggle/working/my_code/tkbc/preprocess_continuous_time.py
# Out:
# python3: can't open file '/kaggle/working/my_code/tkbc/preprocess_continuous_time.py': [Errno 2] No such file or directory

# %%
# !ls /kaggle/working/my_code/tkbc/scripts
# !chmod +x /kaggle/working/my_code/tkbc/scripts/train_continuous_pairre.sh
# !ls -l /kaggle/working/my_code/tkbc/scripts/train_continuous_pairre.sh
# !bash /kaggle/working/my_code/tkbc/scripts/train_continuous_pairre.sh
# Out:
# ls: cannot access '/kaggle/working/my_code/tkbc/scripts': No such file or directory
# chmod: cannot access '/kaggle/working/my_code/tkbc/scripts/train_continuous_pairre.sh': No such file or directory
# ls: cannot access '/kaggle/working/my_code/tkbc/scripts/train_continuous_pairre.sh': No such file or directory
# bash: /kaggle/working/my_code/tkbc/scripts/train_continuous_pairre.sh: No such file or directory

# %%
import shutil
import os

# Tên file zip kết quả
output_filename = "/kaggle/working/ket_qua_training"

# Thư mục bạn muốn nén (thường là folder chứa model đã lưu)
# Dựa trên code của bạn, model có thể nằm ở thư mục hiện tại hoặc folder 'models'
# Ở đây mình nén luôn cả thư mục 'working' để chắc ăn không sót gì
dir_to_zip = "/kaggle/working/my_code"

try:
    shutil.make_archive(output_filename, 'zip', dir_to_zip)
    print(f"Đã nén xong! File nằm tại: {output_filename}.zip")
except Exception as e:
    print(f"Lỗi khi nén: {e}")
# Out:
# Lỗi khi nén: [Errno 2] No such file or directory: '/kaggle/working/my_code'
